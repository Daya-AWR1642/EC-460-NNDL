# %%
import numpy as np
import pandas as pd
import pylab as pl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
data = pd.read_csv('Advertising Budget and Sales.csv')

# %%
data1 = data.iloc[:,1:5]

# %%
data1
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 0               230.1                 37.8                     69.2       22.1
# 1                44.5                 39.3                     45.1       10.4
# 2                17.2                 45.9                     69.3        9.3
# 3               151.5                 41.3                     58.5       18.5
# 4               180.8                 10.8                     58.4       12.9
# ..                ...                  ...                      ...        ...
# 195              38.2                  3.7                     13.8        7.6
# 196              94.2                  4.9                      8.1        9.7
# 197             177.0                  9.3                      6.4       12.8
# 198             283.6                 42.0                     66.2       25.5
# 199             232.1                  8.6                      8.7       13.4
#
# [200 rows x 4 columns]

# %%
data1.describe()
# Out:
#        TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  \
# count        200.000000           200.000000               200.000000
# mean         147.042500            23.264000                30.554000
# std           85.854236            14.846809                21.778621
# min            0.700000             0.000000                 0.300000
# 25%           74.375000             9.975000                12.750000
# 50%          149.750000            22.900000                25.750000
# 75%          218.825000            36.525000                45.100000
# max          296.400000            49.600000               114.000000
#
#         Sales ($)
# count  200.000000
# mean    14.022500
# std      5.217457
# min      1.600000
# 25%     10.375000
# 50%     12.900000
# 75%     17.400000
# max     27.000000

# %%
cor = data1.corr()
plt.figure(figsize = (4,4))
sns.heatmap(cor,annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
sns.pairplot(data1)

# %%
x_data1 = np.array([data.iloc[:,1:4]])

# %%
x_data1
# Out:
# array([[[230.1,  37.8,  69.2],
#         [ 44.5,  39.3,  45.1],
#         [ 17.2,  45.9,  69.3],
#         [151.5,  41.3,  58.5],
#         [180.8,  10.8,  58.4],
#         [  8.7,  48.9,  75. ],
#         [ 57.5,  32.8,  23.5],
#         [120.2,  19.6,  11.6],
#         [  8.6,   2.1,   1. ],
#         [199.8,   2.6,  21.2],
#         [ 66.1,   5.8,  24.2],
#         [214.7,  24. ,   4. ],
#         [ 23.8,  35.1,  65.9],
#         [ 97.5,   7.6,   7.2],
#         [204.1,  32.9,  46. ],
#         [195.4,  47.7,  52.9],
#         [ 67.8,  36.6, 114. ],
#         [281.4,  39.6,  55.8],
#         [ 69.2,  20.5,  18.3],
#         [147.3,  23.9,  19.1],
#         [218.4,  27.7,  53.4],
#         [237.4,   5.1,  23.5],
#         [ 13.2,  15.9,  49.6],
#         [228.3,  16.9,  26.2],
#         [ 62.3,  12.6,  18.3],
#         [262.9,   3.5,  19.5],
#         [142.9,  29.3,  12.6],
#         [240.1,  16.7,  22.9],
#         [248.8,  27.1,  22.9],
#         [ 70.6,  16. ,  40.8],
# ...

# %%
x_data1.shape
# Out:
# (1, 200, 3)

# %%
x_data = x_data1.reshape(200,3)

# %%
x_data.shape
# Out:
# (200, 3)

# %%
y_data = np.array([data.iloc[:,4]])

# %%
y_data
# Out:
# array([[22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#         17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 12.5,
#          5.6, 15.5,  9.7, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,
#         17.4,  9.5, 12.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 12.9,
#          8.5, 14.9, 10.6, 23.2, 14.8,  9.7, 11.4, 10.7, 22.6, 21.2, 20.2,
#         23.7,  5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 15.7, 14. , 18. ,  9.3,
#          9.5, 13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#         14.2,  5.3, 11. , 11.8, 12.3, 11.3, 13.6, 21.7, 15.2, 12. , 16. ,
#         12.9, 16.7, 11.2,  7.3, 19.4, 22.2, 11.5, 16.9, 11.7, 15.5, 25.4,
#         17.2, 11.7, 23.8, 14.8, 14.7, 20.7, 19.2,  7.2,  8.7,  5.3, 19.8,
#         13.4, 21.8, 14.1, 15.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,
#          7. , 11.6, 15.2, 19.7, 10.6,  6.6,  8.8, 24.7,  9.7,  1.6, 12.7,
#          5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1,
# ...

# %%
y_data.shape
# Out:
# (1, 200)

# %%
y_data = y_data.reshape(-1,1)

# %%
from sklearn.preprocessing import StandardScaler
sc1 = StandardScaler()
x_norm = sc1.fit_transform(x_data)
y_norm = sc1.fit_transform(y_data)

# %%
x_norm
# Out:
# array([[ 9.69852266e-01,  9.81522472e-01,  1.77894547e+00],
#        [-1.19737623e+00,  1.08280781e+00,  6.69578760e-01],
#        [-1.51615499e+00,  1.52846331e+00,  1.78354865e+00],
#        [ 5.20496822e-02,  1.21785493e+00,  1.28640506e+00],
#        [ 3.94182198e-01, -8.41613655e-01,  1.28180188e+00],
#        [-1.61540845e+00,  1.73103399e+00,  2.04592999e+00],
#        [-1.04557682e+00,  6.43904671e-01, -3.24708413e-01],
#        [-3.13436589e-01, -2.47406325e-01, -8.72486994e-01],
#        [-1.61657614e+00, -1.42906863e+00, -1.36042422e+00],
#        [ 6.16042873e-01, -1.39530685e+00, -4.30581584e-01],
#        [-9.45155670e-01, -1.17923146e+00, -2.92486143e-01],
#        [ 7.90028350e-01,  4.96973404e-02, -1.22232878e+00],
#        [-1.43908760e+00,  7.99208859e-01,  1.62704048e+00],
#        [-5.78501712e-01, -1.05768905e+00, -1.07502697e+00],
#        [ 6.66253447e-01,  6.50657027e-01,  7.11007392e-01],
#        [ 5.64664612e-01,  1.65000572e+00,  1.02862691e+00],
# ...

# %%
y_norm
# Out:
# array([[ 1.55205313],
#        [-0.69604611],
#        [-0.90740587],
#        [ 0.86033029],
#        [-0.21568303],
#        [-1.31091086],
#        [-0.42704278],
#        [-0.15803946],
#        [-1.77205942],
#        [-0.65761706],
#        [-1.04190753],
#        [ 0.64897053],
#        [-0.92662039],
#        [-0.83054778],
#        [ 0.9564029 ],
#        [ 1.6096967 ],
#        [-0.29254112],
#        [ 1.99398717],
#        [-0.5231154 ],
#        [ 0.11096387],
#        [ 0.76425767],
#        [-0.29254112],
#        [-1.61834324],
#        [ 0.28389458],
#        [-0.83054778],
#        [-0.38861374],
#        [ 0.18782197],
#        [ 0.36075268],
#        [ 0.93718838],
#        [-0.67683159],
#        [ 1.41755147],
#        [-0.40782826],
#        [-0.8497623 ],
#        [ 0.64897053],
#        [-0.86897682],
#        [-0.23489755],
#        [ 2.1861324 ],
#        [ 0.1301784 ],
#        [-0.75368968],
#        [ 1.43676599],
#        [ 0.49525434],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x_norm,y_norm,test_size = 0.2,random_state=42)

# %%
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (160, 3) (40, 3) (160, 1) (40, 1)

# %% [markdown]
# ### Gradient Descendent Algorithms

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[0.73603268, 0.53837398, 0.0115254 ]])

# %%
model.intercept_
# Out:
# array([0.00374765])

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[ 0.45836711],
#        [ 1.31953474],
#        [ 1.4471117 ],
#        [-0.65598334],
#        [ 1.55443059],
#        [-0.17617956],
#        [ 1.35168253],
#        [-1.26075897],
#        [-0.07996205],
#        [ 0.21761786],
#        [-0.955765  ],
#        [-1.4159599 ],
#        [ 0.06207153],
#        [-0.98359274],
#        [-0.83254795],
#        [-0.35692056],
#        [-1.01572122],
#        [ 0.43089963],
#        [-0.71956549],
#        [ 0.92394785],
#        [ 1.06407466],
#        [-0.14823339],
#        [-0.32401317],
#        [ 1.39967261],
#        [-1.19035835],
#        [-1.5780745 ],
#        [ 1.29410436],
#        [-0.39219133],
#        [-0.9297916 ],
#        [-1.05983486],
#        [-0.29898419],
#        [-0.77225534],
#        [ 1.41518249],
#        [-0.34064205],
#        [ 0.81548654],
#        [ 1.17499936],
#        [ 0.00627163],
#        [ 1.31266166],
#        [-0.57740717],
#        [-1.8164457 ]])

# %% [markdown]
# ### Model Evaluation Using Visualization
# #### Regression Plot

# %%
fig,axes = plt.subplots(1,3,figsize = (18,6))
sns.regplot(x = 'TV Ad Budget ($)',y = 'Sales ($)',data = data1,ax = axes[0])
sns.regplot(x = 'Radio Ad Budget ($)',y = 'Sales ($)',data = data1,ax = axes[1])
sns.regplot(x = 'Newspaper Ad Budget ($)',y = 'Sales ($)',data = data1,ax = axes[2])

# for ax in axes:
#     ax.set_ylim(0,)
    
axes[0].set_title('TV Ad Budget vs. Sales')
axes[1].set_title('Radio Ad Budget vs. Sales')
axes[2].set_title('Newspaper Ad Budget vs. Sales')
plt.tight_layout()  
plt.show()

# %% [markdown]
# ### Residual Plot

# %%
fig,axes = plt.subplots(1,3,figsize = (18,6))
sns.residplot(x = 'TV Ad Budget ($)', y = 'Sales ($)',data = data1, ax = axes[0])
sns.residplot(x = 'Radio Ad Budget ($)', y = 'Sales ($)',data = data1, ax = axes[1])
sns.residplot(x = 'Newspaper Ad Budget ($)', y = 'Sales ($)',data = data1,ax = axes[2])
# Out:
# <Axes: xlabel='Newspaper Ad Budget ($)', ylabel='Sales ($)'>

# %% [markdown]
# ### Distribution Plot

# %%
plt.figure(figsize=(6, 6))
# col = ''
sns.kdeplot(Y_test, color="r", label="Actual Value")
sns.kdeplot(y_pred, color="b", label="Fitted Values")
plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Density')
plt.legend()

# %% [markdown]
# ### Manual

# %%
def init_para(x):
    w = np.zeros((1,x.shape[1]))
    b = np.zeros((1,1))
    return w,b

def fwd_path(x,w,b):
    y_pred = np.matmul(w,x.T)+b
    return y_pred

def mse_loss(y_pred,y_true):
    loss = np.mean((y_pred-y_true)**2)
    return loss

def grad_para(x,y_pred,y_true):
    y_pred = np.reshape(y_pred,(len(y_true),1))
    
    d = 2*(y_pred-y_true)
    
    dw = np.matmul(d.T,x) # for BGD and MBGD
    
    # dw = d*x for SGD
    
    db = d.sum()
    return dw,db

def para_updt(w,b,dw,db,lr):
    db = np.reshape(db,b.shape)
    w = w - (lr*dw)
    b = b - (lr*db)
    return w,b

# %%
lr = 0.0001
epochs = 200

cost_history = np.zeros(epochs)
w,b = init_para(X_train)

for i in range(epochs):
    y_pred = fwd_path(X_train,w,b)
    cost_history[i] = mse_loss(y_pred,Y_train)
    dw,db = grad_para(X_train,y_pred,Y_train)
    w,b  = para_updt(w,b,dw,db,lr)
    
print(w,b)
# Out:
# [[0.7350878  0.53333221 0.017621  ]] [[0.00402547]]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt
print("MAE: ", mean_absolute_error(y_test,y_pred))
print("MSE: ",np.sqrt(mean_squared_error(Y_test,y_pred)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 from sklearn.metrics import mean_absolute_error, mean_squared_error
#       2 from math import sqrt
# ----> 3 print("MAE: ", mean_absolute_error(y_test,y_pred))
#       4 print("MSE: ",np.sqrt(mean_squared_error(Y_test,y_pred)))
#
# NameError: name 'y_test' is not defined
